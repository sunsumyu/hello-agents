# %% [markdown]
# # MADF: HelloAgents 多智能体圆桌讨论
#
# 本 Notebook 是 Hello-Agents 共创项目的最小演示入口。主持人与嘉宾直接继承 `SimpleAgent`，角色研究使用 `ReActAgent` 和 StepSearch Tool。运行前请按 `.env.example` 配置 StepFun API Key。

# %%
from demo_helloagents import run_demo

transcript = run_demo("人工智能应该如何参与公共决策？")
transcript

# %% [markdown]
# ## 验证要点
#
# 输出应包含主持人开场、嘉宾思考与发言、阶段总结和闭幕。完整 Web 应用请按 README 使用 Docker Compose 启动。
